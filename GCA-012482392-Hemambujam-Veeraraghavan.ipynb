# %% [markdown]
# When a bank receives a loan application, based on the applicant’s profile the bank has to make a decision regarding whether to go ahead with the loan approval or not. Two types of risks are associated with the bank’s decision –
#
# If the applicant is a good credit risk, i.e. is likely to repay the loan, then not approving the loan to the person results in a loss of business to the bank
# If the applicant is a bad credit risk, i.e. is not likely to repay the loan, then approving the loan to the person results in a financial loss to the bank
# Objective of Analysis:
#
# Minimization of risk and maximization of profit on behalf of the bank.
#
# To minimize loss from the bank’s perspective, the bank needs a decision rule regarding who to give approval of the loan and who not to. An applicant’s demographic and socio-economic profiles are considered by loan managers before a decision is taken regarding his/her loan application.
#
# The German Credit Data contains data on 20 variables and the classification whether an applicant is considered a Good or a Bad credit risk for 1000 loan applicants.
#
# A predictive model developed on this data is expected to provide a bank manager guidance for making a decision whether to approve a loan to a prospective applicant based on his/her profiles.

# %% [markdown]
# Description of the German credit dataset.
#
# 1. Title: German Credit data
#
# 2. Source Information
#
# Professor Dr. Hans Hofmann
# Institut f"ur Statistik und "Okonometrie
# Universit"at Hamburg
# FB Wirtschaftswissenschaften
# Von-Melle-Park 5
# 2000 Hamburg 13
#
# 3. Number of Instances:  1000
#
# Two datasets are provided.  the original dataset, in the form provided
# by Prof. Hofmann, contains categorical/symbolic attributes and
# is in the file "german.data".
#
# For algorithms that need numerical attributes, Strathclyde University
# produced the file "german.data-numeric".  This file has been edited
# and several indicator variables added to make it suitable for
# algorithms which cannot cope with categorical variables.   Several
# attributes that are ordered categorical (such as attribute 17) have
# been coded as integer.    This was the form used by StatLog.
#
#
# 6. Number of Attributes german: 20 (7 numerical, 13 categorical)
#    Number of Attributes german.numer: 24 (24 numerical)
#
#
# 7.  Attribute description for german
#
# Attribute 1:  (qualitative)                     **(4 items -> 2 bits)**
# 	       Status of existing checking account
#                A11 :      ... <    0 DM
# 	       A12 : 0 <= ... <  200 DM
# 	       A13 :      ... >= 200 DM /
# 		     salary assignments for at least 1 year
#                A14 : no checking account
#
# Attribute 2:  (numerical)                    **(Gaussian normalization)**
# 	      Duration in month
#
# Attribute 3:  (qualitative) **(4 items -> 2 bits)**
# 	      Credit history
# 	      A30 : no credits taken/
# 		    all credits paid back duly
#               A31 : all credits at this bank paid back duly
# 	      A32 : existing credits paid back duly till now
#               A33 : delay in paying off in the past
# 	      A34 : critical account/
# 		    other credits existing (not at this bank)
#
# Attribute 4:  (qualitative)
# 	      Purpose
# 	      A40 : car (new)
# 	      A41 : car (used)
# 	      A42 : furniture/equipment
# 	      A43 : radio/television
# 	      A44 : domestic appliances
# 	      A45 : repairs
# 	      A46 : education
# 	      A47 : (vacation - does not exist?)
# 	      A48 : retraining
# 	      A49 : business
# 	      A410 : others
#
# Attribute 5:  (numerical)                    **(Gaussian normalization)**
# 	      Credit amount
#
# Attibute 6:  (qualitative)
# 	      Savings account/bonds
# 	      A61 :          ... <  100 DM
# 	      A62 :   100 <= ... <  500 DM
# 	      A63 :   500 <= ... < 1000 DM
# 	      A64 :          .. >= 1000 DM
#               A65 :   unknown/ no savings account
#
# Attribute 7:  (qualitative)
# 	      Present employment since
# 	      A71 : unemployed
# 	      A72 :       ... < 1 year
# 	      A73 : 1  <= ... < 4 years
# 	      A74 : 4  <= ... < 7 years
# 	      A75 :       .. >= 7 years
#
# Attribute 8:  (numerical)                       **(Gaussian normalization)**
# 	      Installment rate in percentage of disposable income
#
# Attribute 9:  (qualitative)
# 	      Personal status and sex
# 	      A91 : male   : divorced/separated
# 	      A92 : female : divorced/separated/married
#               A93 : male   : single
# 	      A94 : male   : married/widowed
# 	      A95 : female : single
#
# Attribute 10: (qualitative)
# 	      Other debtors / guarantors
# 	      A101 : none
# 	      A102 : co-applicant
# 	      A103 : guarantor
#
# Attribute 11: (numerical)                          **(Gaussian normalization)**
# 	      Present residence since
#
#
# Attribute 12: (qualitative) **(4 items -> 2 bits)**
# 	      Property
# 	      A121 : real estate
# 	      A122 : if not A121 : building society savings agreement/
# 				   life insurance
#               A123 : if not A121/A122 : car or other, not in attribute 6
# 	      A124 : unknown / no property
#
#
# Attribute 13: (numerical)                       **(Gaussian normalization)**
# 	      Age in years
#
# Attribute 14: (qualitative)
# 	      Other installment plans
# 	      A141 : bank
# 	      A142 : stores
# 	      A143 : none
#
# Attribute 15: (qualitative)
# 	      Housing
# 	      A151 : rent
# 	      A152 : own
# 	      A153 : for free
#
# Attribute 16: (numerical)                       **(Gaussian normalization)**
#               Number of existing credits at this bank
#
# Attribute 17: (qualitative) **(4 items -> 2 bits)**
# 	      Job
# 	      A171 : unemployed/ unskilled  - non-resident
# 	      A172 : unskilled - resident
# 	      A173 : skilled employee / official
# 	      A174 : management/ self-employed/
# 		     highly qualified employee/ officer
#
# Attribute 18: (numerical)                       **(Gaussian normalization)**
# 	      Number of people being liable to provide maintenance for
#
# Attribute 19: (qualitative)                              **(Binary)**
# 	      Telephone
# 	      A191 : none
# 	      A192 : yes, registered under the customers name
#
# Attribute 20: (qualitative)                              **(Binary)**
# 	      foreign worker
# 	      A201 : yes
# 	      A202 : no
#
#
#
# 8.  Cost Matrix
#
# This dataset requires use of a cost matrix (see below)
#
#
#       1        2
# ----------------------------
#   1   0        1
# -----------------------
#   2   5        0
#
# (1 = Good,  2 = Bad)
#
# the rows represent the actual classification and the columns
# the predicted classification.
# It is worse to class a customer as good when they are bad (5),
# than it is to class a customer as bad when they are good (1).

# %% [markdown]
# Notes:
# - DM stands for Deutsche Mark, the unit of currency in Germany.
# - Owns_telephone: German phone rates are very high, so fewer people own telephones.
# - Foreign_worker: There are millions of foreign worker working in Germany
# - 20 attributes used in judging a loan applicant. The goal is the classify the applicant into one of two categories, good or bad, which is the last attribute
# - This dataset is typical of data used in data mining: we have 1000 records.

# %% [markdown]
# 1. First We need to analyze the data set (use the numerical version). Visualize the Data Set. This can be done in various ways, from single visualizations to doing pairplot
# 2. Cluster the data, use GMM and then k-means. visulaize it. Interpret it. Compare.
# 3. use linear regression to see thre trends, interpret them,
# 4. Then classify the data -- pick a couple of good things to classify by -- use logistic regression for a binary classification (maybe default no default) (maybe other attribute) and
# 5. use Random Forest to classify if they will default or not.

# %% [markdown]
# # Data Analysis

# %% [markdown]
# The Spreadsheet that was provided as part of this assignment throws light on the credit dataset that explains the approval of granting the users with loan or not. As part of this assignment, the dataset was prepared in such a way to lable those attributes to make the necessary co-relations inorder to come up with a meaningful data analysis.

# %% [markdown]
# #### Data Preparation

# %% [markdown]
# In Order to access data from the spreadsheet, we use the panda library. This library lets us access, read, write and maniputate data using python.

# %%
import pandas as pd

# %% [markdown]
# As part of this assignment, on accessing the provided dataset, we have added labels to these numerical values to make them more meaningful.

# %%
label = pd.read_excel("german.xlsx",
                    names = ['Status of existing checking account', 
                             'Duration in month', 
                             'Credit history', 
                             'Credit amount', 
                             'Savings account/bonds',
                             'Present employment since',
                             'Personal status and sex',
                             'Present residence since',
                             'Property',
                             'Age in years',
                             'Other installment plans',
                             'Number of existing credits at this bank',
                             'Number of people being liable to provide maintenance fo',
                             'Telephone',
                             'foreign worker',
                             'Purpose-- car(new)',
                             'Purpose--car(used)',
                             'Other debtors / guarantors-- None', 
                             'Other debtors / guarantors-- co-applicant',
                             'Housin--rent', 
                             'Housing--own',
                             'Job--unemployed/ unskilled  - non-resident',
                             'Job--unskilled - resident', 
                             'Job--skilled employee / official',
                             'Result'
                            ])

# %% [markdown]
# Having added the labels, we try and print the number of rows and columns we see int he dataset, to ensure we have labeled them as required.

# %%
print(label.shape)
# Out:
# (999, 25)

# %% [markdown]
# We see a row missing in the interpretted dataset. From the Spreadsheet, I understand that the numebr of rows in the dataset is 1000, while only 999 is present in the intrepretted dataset here. As part of troubleshooting, we find that the first row of the dataset has been missed while accessing the data.

# %%
print(label.iloc[0])
# Out:
# Status of existing checking account                         2
# Duration in month                                          48
# Credit history                                              2
# Credit amount                                              60
# Savings account/bonds                                       1
# Present employment since                                    3
# Personal status and sex                                     2
# Present residence since                                     2
# Property                                                    1
# Age in years                                               22
# Other installment plans                                     3
# Number of existing credits at this bank                     1
# Number of people being liable to provide maintenance fo     1
# Telephone                                                   1
# foreign worker                                              1
# ...

# %% [markdown]
# Once we have identified the missing row, we add it manually below, so we dont have to work on a dataset that might be missing a crucial row, or to keep adding it while working on the dataset in future.

# %%
label.loc[-1] = [1,6,4,12,5,5,3,4,1,67,3,2,1,2,1,0,0,1,0,0,1,0,0,1,1]

# %% [markdown]
# Once we have added the missing row, we make sure that the index values point to the right column and sort the index using inplace method to sort dataframe by index

# %%
label.index = label.index + 1
label.sort_index(inplace=True)

# %% [markdown]
# Once we have added the index, we now check the number of rows to ensure we have all the data accessible for the assignment.

# %%
print(label.shape)
# Out:
# (1000, 25)

# %% [markdown]
# Now that we have all the 1000 rows as part of the dataset, we display them below for better understanding as this would help in data visualization:

# %%
print(label.iloc[0])
# Out:
# Status of existing checking account                         1
# Duration in month                                           6
# Credit history                                              4
# Credit amount                                              12
# Savings account/bonds                                       5
# Present employment since                                    5
# Personal status and sex                                     3
# Present residence since                                     4
# Property                                                    1
# Age in years                                               67
# Other installment plans                                     3
# Number of existing credits at this bank                     2
# Number of people being liable to provide maintenance fo     1
# Telephone                                                   2
# foreign worker                                              1
# ...

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# To understand the co-relation between the different columns on the dataset, we perfom ploting using the libraries that are present in python to help us make meaningfull assumstion about the given dataset. This is a very crutial stage as we get to see the relationship between the given dataset which will in turn help us understand the dataset better for future analysis and predictions

# %% [markdown]
# #### Simple statistical analysis of the dataset

# %%
print("Max and Min of installment plans:", label['Other installment plans'].max(), label['Other installment plans'].min())
print("Max and min Housing--own:", label['Housing--own'].max(), label['Housing--own'].min())
print("Max and min foreign workers:", label['foreign worker'].max(), label['foreign worker'].min())
print("Results look good for:", label.loc[label['Result'] == 1].shape[0], ", look bad for:", label.loc[label['Result'] == 2].shape[0])
# Out:
# Max and Min of installment plans: 3 1
# Max and min Housing--own: 1 0
# Max and min foreign workers: 2 1
# Results look good for: 700 , look bad for: 300

# %% [markdown]
# #### Performing cross tabulation for better data visualisation
#
# Plotting those who use telephone to analysis how often they could be reached in terms of reminding them amount an upcoming due or other such details.

# %%
pd.crosstab(dfs['Telephone'],dfs['Result'], normalize='index',margins=True)
# Out:
# Result            1         2
# Telephone
# 1          0.686242  0.313758
# 2          0.719603  0.280397
# All        0.699700  0.300300

# %% [markdown]
# #### Histogram Plot of the data set
#
# To plot those customer who use telephones against those who donot

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
label[label['Result']==2]['Telephone'].value_counts().sort_index(ascending=True).plot('bar', ax=ax, legend=True)

# %% [markdown]
# Since ploting the number of telephone havent been much fruitful, we will now access on the relationship between accessing the credit amount that each customers owe to the bank:

# %%
plt.hist(label['Credit amount'],density=1, bins=40)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Now that we have the data of the amount that is owed to the bank, we'll now try and make a relation between the amount that is owed to the bank against the good results a.k.a those who play back and the bad results a.k.a those who do not.

# %%
plt.hist(label[label['Result']==2]['Credit amount'],density=1, bins=40)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ##### Pair Plotting

# %% [markdown]
# To plot pair-wise relationship to the dataset. This will help us understanding the data set even better and make sure we choos eth right columns for the future part of this assignment. We use the "seaborn" visualiation library to pair plot, as shown below:

# %%
label_new = label[(label['Result']==2) & (label['Telephone']==2)][[ 
                             'Duration in month', 
                             'Age in years',
                             ]]
# Seaborn visualization library
import seaborn as sea
# Create the default pairplot
sea.pairplot(label_new)

# %%
#Normal plotting of the dataset of result columns VS the age column
import numpy as np
Y_Output= np.array(label['Result'])
#X_Input = dfs.drop(['Result'], axis=1)
X_Input = np.array(label[['Age in years','Duration in month']])
plt.plot(X_Input[:,0], X_Input[:,1])
plt.show()

# %% [markdown]
# ## Clustering

# %% [markdown]
# There are two clustering algorithm we are using:
#
# 1. K-Means
# 2. GMM
#
# #### Gaussian Mixture Model:
#
# is a clustering method that would group data point into full, spherical or dig as mentioned in the code

# %%
from matplotlib.patches import Ellipse

def draw_ellipse(position, covariance, ax=None, **kwargs):
        """Draw an ellipse with a given position and covariance"""
        ax = ax or plt.gca()
    
    # Convert covariance to principal axes
        if covariance.shape == (2, 2):
            U, s, Vt = np.linalg.svd(covariance)
            angle = np.degrees(np.arctan2(U[1, 0], U[0, 0]))
            width, height = 2 * np.sqrt(s)
        else:
            angle = 0
            width, height = 2 * np.sqrt(covariance)
    
    # Draw the Ellipse
        for nsig in range(1, 4):
            ax.add_patch(Ellipse(position, nsig * width, nsig * height,
                             angle, **kwargs))
    
def plot_gmm(gmm, X, label=True, ax=None):
    ax = ax or plt.gca()
    labels = gmm.fit(X).predict(X)
    if label:
        ax.scatter(X[:, 0], X[:, 1], c=labels, s=40, cmap='viridis', zorder=2)
    else:
        ax.scatter(X[:, 0], X[:, 1], s=40, zorder=2)
    ax.axis('auto')

    w_factor = 0.2 / gmm.weights_.max()
    for pos, covar, w in zip(gmm.means_, gmm.covariances_, gmm.weights_):
        draw_ellipse(pos, covar, alpha=w * w_factor)
            
from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=4).fit(X_Input)
labels = gmm.predict(X_Input)
gmm = GaussianMixture(n_components=4, covariance_type='full', random_state=2)
plot_gmm(gmm, X_Input)

# %% [markdown]
# #### KMeans:
#
# The idea is to find the have a number of centroid pre-configured to the dataset and using the Elbow funtion, find the K value to make meaningful visualisation. For now, lets start with the k value to be 7:

# %%
#KMeansimport numpy as np
import seaborn as sea; sea.set()  # for plot styling
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=6)
kmeans.fit(X_Input)
y_kmeans = kmeans.predict(X_Input)
plt.scatter(X_Input[:, 0], X_Input[:, 1], c=y_kmeans, s=50, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1],  s=200, alpha=0.5);

# %% [markdown]
# These 6 centroid shown in different colors are the clusters that are formed around the 6 centroids. now to find the right value for K, we use the elbow method. The poin at which the Elbow bend happens depicts the right vlaue of K for the given dataset:

# %%
from scipy.spatial.distance import cdist
variations = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(X_Input)
    kmeanModel.fit(X_Input)
    variations.append(sum(np.min(cdist(X_Input, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / X_Input.shape[0])

# Plot the elbow
plt.plot(K, variations, 'bx-')
plt.xlabel('k')
plt.ylabel('Variations')
plt.title('The Elbow Method depicting the optimal k vlaue for the dataset')
plt.show()

# %% [markdown]
# #### Thus the optimal value of the K is 4 and the GMM plot support this k value.

# %% [markdown]
# # Linear Regression

# %% [markdown]
# In order to perform Linear regression, lets split up the data into 70% for trining and 30% for testing. this would help us with accessing the prediction and accuracy of our model:

# %%
from sklearn.model_selection import train_test_split
X_training, X_testing, y_training, y_testing = train_test_split(X_Input[:,0], X_Input[:,1], test_size=0.3, random_state=1)
print(X_training.shape, y_training.shape)
print(X_testing.shape, y_testing.shape)

X_training = np.array(X_training)
X_training = X_training.reshape((len(X_training), 1))
X_testing = np.array(X_testing)
X_testing = X_testing.reshape((len(X_testing), 1))
y_training = np.array(y_training)
y_training = y_training.reshape((len(y_training), 1))
y_testing = np.array(y_testing)
y_testing = y_testing.reshape((len(y_testing), 1))
# Out:
# (700,) (700,)
# (300,) (300,)

# %% [markdown]
# Once we have split the dataset into trainign and testing, we can now perform linear regression on them and based ont eh outcome of the testing dataset, use the 30% to test the outcome of the repdicted dataset:

# %%
from sklearn import datasets, linear_model, metrics
from sklearn.metrics import mean_squared_error, r2_score

reg = linear_model.LinearRegression() 

# Train the model using the training sets
reg.fit(X_training, y_training) 

# Make predictions using the testing set
y_predicting = reg.predict(X_testing)

print('Intercept: ', reg.intercept_)
print('Coefficients: ', reg.coef_)
print('Variance score: {}'.format(reg.score(y_testing, y_predicting)))
print("Mean squared error: %.2f" %mean_squared_error(y_testing, y_predicting))
print("R squared : %.2f" %r2_score(y_testing, y_predicting))

# Plot outputs
plt.scatter(X_testing, y_testing,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Intercept:  [21.04906163]
# Coefficients:  [[-0.00393845]]
# Variance score: -3.4055830998060035
# Mean squared error: 152.04
# R squared : 0.00

# %% [markdown]
# Thus logistic regression draws a plane in the dataset, which gives us a vague idea on the average amount that is owed to tbe back when ran against the age of those who owe to the bank. Since this doesnt give us a clearer picture of the situation, we will now go on to try the Logistic regression method.

# %% [markdown]
# # Logistic Regression

# %% [markdown]
#  The logistic regression model is a very robust model which works on more of a Yes/No model, unlike linear regression. This will work on the data points on the plot and strive to acheive maximum coverage of the dataset.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix
BinaryResult=label['Result'].replace(2,0)

Features= label[['Purpose-- car(new)','Purpose--car(used)','foreign worker','Number of existing credits at this bank','Credit history','Job--unemployed/ unskilled  - non-resident','Job--unskilled - resident','Job--skilled employee / official','Age in years','Other debtors / guarantors-- None','Other debtors / guarantors-- co-applicant']]
X_training, X_testing, y_training, y_testing = train_test_split(Features, BinaryResult, test_size=0.30, random_state=101)
logmodel = LogisticRegression()
logmodel.fit(X_training,y_training)
predictions = logmodel.predict(X_testing)
print(classification_report(y_testing,predictions))
matrix=confusion_matrix(y_testing,predictions)
print("Confusion matrix:\n",matrix)
print("Cost: ", matrix[0][1]+matrix[1][0]*5)

# ROC should be as far away from red line towards top left
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_testing, logmodel.predict(X_testing))
fpr, tpr, thresholds = roc_curve(y_testing, logmodel.predict_proba(X_testing)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
# Out:
#              precision    recall  f1-score   support
#
#           0       0.76      0.17      0.27        96
#           1       0.71      0.98      0.82       204
#
# avg / total       0.73      0.72      0.65       300
#
# Confusion matrix:
#  [[ 16  80]
#  [  5 199]]
# Cost:  105

# %% [markdown]
# Thus the logistic regression model's output is acessed by the confusion matrix and the precision of this model comes about 76% which is ideal for our usecase.

# %% [markdown]
# # Naive Bayers

# %%
#Naive Bayes
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
gnb = GaussianNB()
x=label.drop(['Result'], axis=1)
y=BinaryResult
x_training, x_testing, y_training, y_testing = train_test_split(x, y, test_size=0.3)
gnb.fit(x,y)
y_pred = gnb.predict(x_testing)
print(confusion_matrix(y_testing,y_pred))
print('\n')
print(classification_report(y_testing,y_pred))
print(accuracy_score(y_testing,y_pred))
# Out:
# [[ 55  28]
#  [ 50 167]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.52      0.66      0.59        83
#           1       0.86      0.77      0.81       217
#
# avg / total       0.76      0.74      0.75       300
#
# 0.74

# %% [markdown]
# # SVM

# %%
#SVM
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report,confusion_matrix
x=label.drop(['Result'], axis=1)
X_training, X_testing, y_training, y_testing = train_test_split(x, y, test_size=0.30)
model = SVC()
model.fit(X_training,y_training)
predictions = model.predict(X_testing)
print(confusion_matrix(y_testing,predictions))
print('\n')
print(classification_report(y_testing,predictions))
# Out:
# [[ 10  78]
#  [ 14 198]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.42      0.11      0.18        88
#           1       0.72      0.93      0.81       212
#
# avg / total       0.63      0.69      0.63       300

# %% [markdown]
# # KNN

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import train_test_split
x=label.drop(['Result'], axis=1)
X_training, X_testing, y_training, y_testing = train_test_split(x, y, test_size=0.33, random_state=42)
knn=KNeighborsClassifier(n_neighbors=23)
knn.fit(X_training,y_training)
pred=knn.predict(X_testing)
print(confusion_matrix(y_testing,pred))
print('\n')
print(classification_report(y_testing,pred))


#elbow for knn
error_rate=[]  
for i in range (1,40):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_training,y_training)
    pred_i=knn.predict(X_testing)
    error_rate.append(np.mean(pred_i!=y_testing))

#plotting
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# C:\Users\Hema\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# [[  9  92]
#  [ 12 217]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.43      0.09      0.15       101
#           1       0.70      0.95      0.81       229
#
# avg / total       0.62      0.68      0.60       330
# Text(0,0.5,'Error Rate')

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import FeatureUnion
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, fbeta_score

features = []
features.append(('pca', PCA(n_components=2)))
features.append(('select_best', SelectKBest(k=6)))
feature_union = FeatureUnion(features)
# create pipeline
estimators = []
estimators.append(('feature_union', feature_union))
estimators.append(('logistic', GaussianNB()))
model = Pipeline(estimators)
# evaluate pipeline
seed = 7
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(model, X_train, y_train, cv=kfold)
print(results.mean())
# Out:
# 0.5757142857142857

# %% [markdown]
# # Decision Tree

# %% [markdown]
# Decision trees are the building blocks of random tree algorithm. Inorder to implement a Random forest, we shall start off with building a decision tree

# %%
#Decision tree
from IPython.display import Image  
from sklearn.externals.six import StringIO
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import pydot
from sklearn.metrics import accuracy_score 
dot_data = StringIO()  
dtree=DecisionTreeClassifier()
features = list(label.columns[0:24])
x=label.drop(['Result'], axis=1)
y=label['Result'].replace(2,'No')
y=y.replace(1,'Yes')
#x
#y
x_training, x_testing, y_training, y_testing = train_test_split(x, y, test_size=0.4)
dtree.fit(x_training,y_training)
y_pred=dtree.predict(x_testing)
y_pred=dtree.predict(x_testing)
print('Accuracy score is:')
print(accuracy_score(y_testing,y_pred))
#we need pass features columns and dtree to graphviz 
export_graphviz(dtree,out_file=dot_data,feature_names=features,filled=True,rounded=True)
graph = pydot.graph_from_dot_data(dot_data.getvalue())
#print (graph)
#print (Image(graph))
Image(graph[0].create_png()) 
#features
# Out:
# Accuracy score is:
# 0.765

# %% [markdown]
# Thus this single decision tree for the given dataset starts with the amount present in the checking account of the customer and goes on making decisions based on the query in the nodes and fall onto the elaves for answers.

# %% [markdown]
# # Random Forest

# %% [markdown]
# Random forests are those that are a cumulation of a numebr of decision trees. Below is the implementation of a random forst for the given dataset:

# %%
#Random Forest
from IPython.display import Image  
from sklearn.externals.six import StringIO
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import pydot
from sklearn.ensemble import RandomForestClassifier
x=label.drop(['Result'], axis=1)
#x=x.drop(['Property'], axis=1)
#x=x.drop(['Personal status and sex'], axis=1)
y=BinaryResult
x_training, x_testing, y_training, y_testing = train_test_split(x, y, test_size=0.3)
rfc=RandomForestClassifier(n_estimators=100,max_depth=3)
rfc.fit(x_training,y_training)
rfc_pred=rfc.predict(x_testing)
print(confusion_matrix(y_testing,rfc_pred))
print('\n')
print(classification_report(y_testing,rfc_pred))

features = list(label.columns[0:24])
tree = rfc.estimators_[5]
export_graphviz(tree, out_file = 'tree.dot', feature_names = features, rounded = True, precision = 1)
(graph, ) = pydot.graph_from_dot_file('tree.dot')
Image(graph.create_png())
# Out:
# [[  3  95]
#  [  1 201]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.75      0.03      0.06        98
#           1       0.68      1.00      0.81       202
#
# avg / total       0.70      0.68      0.56       300

# %% [markdown]
# Thus the gini value plays a crutial role in understading the decision that are to be made as part of the random forest algorithm.

# %% [markdown]
# # Observation:

# %% [markdown]
# Based on the above performed algorithms, We see that the precision score for logistic regression is a 73% while that of a random forest is 70%. Given the complexity of the making decisions in the random forests algorithm, Logistics regression works best for this scenario.
#
# For the analysis performed on the dataset, We worked on the amount a person would owe to a bank based on the given factors in the dataset, and how successful would the customer be when trying to return the amount to the bank a.k.a "good" in the results column. This prediction would help the bank when it comes to deciding to grant a loan to a customer based on his/her age, property value owned and other such criteria, among other requirements.
#
# From Random Forests, we can deduce if a person would be a defaulter using the gini value. This prediction is 70% accurate based on the test performed on the dataset that was set aside for testing and thus this would help the bank to predict if a customer would be a default or not.
#
# Thus a meaningful prediction has been made that would make a difference in the outcome of granting a loan to a customer.
